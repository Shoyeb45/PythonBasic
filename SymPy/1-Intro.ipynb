# %%
from sympy import *

# %%
x, y = symbols('x y')

# %%
x + exp(y)
# Out:
# x + exp(y)

# %%
x, t, z, nu = symbols('x t z nu')

# %%
init_printing(use_unicode=True)

# %%
diff(sin(x)*exp(x), x)
# Out:
#  x           x
# ℯ ⋅sin(x) + ℯ ⋅cos(x)

# %%
integrate(exp(x)*sin(x) + exp(x)*cos(x), x)
# Out:
#  x
# ℯ ⋅sin(x)

# %%
integrate(sin(x**2), (x, -oo, oo))
# Out:
# √2⋅√π
# ─────
#   2

# %%
y = Function('y')
dsolve(Eq(y(t).diff(t, t) - y(t), exp(t)), y(t))
# Out:
#            -t   ⎛     t⎞  t
# y(t) = C₂⋅ℯ   + ⎜C₁ + ─⎟⋅ℯ
#                 ⎝     2⎠

# %%
Matrix([[1, 2], [2, 2]]).eigenvals()
# Out:
# ⎧3   √17     3   √17   ⎫
# ⎨─ - ───: 1, ─ + ───: 1⎬
# ⎩2    2      2    2    ⎭

# %%
Matrix([[1, 2], [2, 2]]).eigenvects()
# Out:
# ⎡⎛            ⎡⎡  √17   1⎤⎤⎞  ⎛            ⎡⎡  1   √17⎤⎤⎞⎤
# ⎢⎜3   √17     ⎢⎢- ─── - ─⎥⎥⎟  ⎜3   √17     ⎢⎢- ─ + ───⎥⎥⎟⎥
# ⎢⎜─ - ───, 1, ⎢⎢   4    4⎥⎥⎟, ⎜─ + ───, 1, ⎢⎢  4    4 ⎥⎥⎟⎥
# ⎢⎜2    2      ⎢⎢         ⎥⎥⎟  ⎜2    2      ⎢⎢         ⎥⎥⎟⎥
# ⎣⎝            ⎣⎣    1    ⎦⎦⎠  ⎝            ⎣⎣    1    ⎦⎦⎠⎦

# %%
besselj(nu, z).rewrite(jn)
# Out:
# √2⋅√z⋅jn(ν - 1/2, z)
# ────────────────────
#          √π

# %%
latex(Integral(cos(x)**2, (x, 0, pi)))
# Out:
# '\\int\\limits_{0}^{\\pi} \\cos^{2}{\\left(x \\right)}\\, dx'

# %% [markdown]
# $\int\limits_{0}^{\pi} \cos^{2}{\left(x \right)} dx$

# %%
help(symbols)
# Out:
# Help on function symbols in module sympy.core.symbol:
#
# symbols(names, *, cls=<class 'sympy.core.symbol.Symbol'>, **args) -> 'Any'
#     Transform strings into instances of :class:`Symbol` class.
#
#     :func:`symbols` function returns a sequence of symbols with names taken
#     from ``names`` argument, which can be a comma or whitespace delimited
#     string, or a sequence of strings::
#
#         >>> from sympy import symbols, Function
#
#         >>> x, y, z = symbols('x,y,z')
#         >>> a, b, c = symbols('a b c')
#
#     The type of output is dependent on the properties of input arguments::
#
#         >>> symbols('x')
#         x
#         >>> symbols('x,')
#         (x,)
#         >>> symbols('x,y')
#         (x, y)
#         >>> symbols(('a', 'b', 'c'))
#         (a, b, c)
#         >>> symbols(['a', 'b', 'c'])
#         [a, b, c]
#         >>> symbols({'a', 'b', 'c'})
#         {a, b, c}
#
#     If an iterable container is needed for a single symbol, set the ``seq``
# ...

# %%
from sympy.abc import y
expr = x + 2 * y

# %%
expr
# Out:
# x + 2⋅y

# %%
expanded_expr = expand(x * expr)

# %%
expanded_expr
# Out:
#  2
# x  + 2⋅x⋅y

# %%
factor(expanded_expr)
# Out:
# x⋅(x + 2⋅y)

# %%
expanded_expr.subs({ x: 2, y: 2})
# Out:
# 12

# %%
a = (x + 1) ** 2
b = x**2 + 2 * x + 1

# %%
simplify(a - b) == 0 # for checking if two expressions are equal
# Out:
# True

# %%
a.equals(b) # evaluates at random point and then check the value
# Out:
# True

# %%
expr1 = 2 * x + 3
expr2 = 6 * x + 3
expr1.equals(expr2)
# Out:
# False

# %%
type(simplify(a - b))
# Out:
# sympy.core.numbers.Zero

# %%
x + Rational(15, Rational(2, 3))
# Out:
# x + 45/2

# %%
x + 1 / 2  # standard python operation
# Out:
# x + 0.5
